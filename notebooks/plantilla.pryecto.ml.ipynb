# %%
import sys

print(sys.version)
print(sys.path)
print("---")
print(sys.executable)
# Out:
# 3.9.13 (main, Aug 25 2022, 18:29:29)
# [Clang 12.0.0 ]
# ['/Users/mariosabater', '/Users/mariosabater/opt/anaconda3/envs/practica0_b/lib/python39.zip', '/Users/mariosabater/opt/anaconda3/envs/practica0_b/lib/python3.9', '/Users/mariosabater/opt/anaconda3/envs/practica0_b/lib/python3.9/lib-dynload', '', '/Users/mariosabater/opt/anaconda3/envs/practica0_b/lib/python3.9/site-packages']
# ---
# /Users/mariosabater/opt/anaconda3/envs/practica0_b/bin/Python

# %%
# primero todas las librerías por bloques
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# opciones de visualización
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df1 = pd.read_csv("/Users/mariosabater/Desktop/practica0/data/raw/Loan_test_set.csv", skiprows=[0])
df2 = pd.read_csv('/Users/mariosabater/Desktop/practica0/data/raw//Loan_training_set_1_4.csv', skiprows=[0])
df3 = pd.read_csv('/Users/mariosabater/Desktop/practica0/data/raw//Loan_training_set_2_4.csv', skiprows=[0])
df4 = pd.read_csv('/Users/mariosabater/Desktop/practica0/data/raw//Loan_training_set_3_4.csv', skiprows=[0])
df5 = pd.read_csv('/Users/mariosabater/Desktop/practica0/data/raw//Loan_training_set_4_4.csv', skiprows=[0])

# %%
# Tendré que juntarlo pero separando training y test
df1['test_set'] = 1
df2['test_set'] = 0
df3['test_set'] = 0
df4['test_set'] = 0
df5['test_set'] = 0

# %%
columns = np.dstack((list(df1.columns), list(df2.columns), list(df3.columns), list(df4.columns), list(df5.columns)))

# %%
coldf = pd.DataFrame(columns[0])

# %%
coldf.head()
# Out:
#                  0                1                2                3  \
# 0               id               id               id               id
# 1        member_id        member_id        member_id        member_id
# 2        loan_amnt        loan_amnt        loan_amnt        loan_amnt
# 3      funded_amnt      funded_amnt      funded_amnt      funded_amnt
# 4  funded_amnt_inv  funded_amnt_inv  funded_amnt_inv  funded_amnt_inv
#
#                  4
# 0               id
# 1        member_id
# 2        loan_amnt
# 3      funded_amnt
# 4  funded_amnt_inv

# %%
df = pd.concat([df1, df2, df3, df4, df5])

# %%
df.shape
# Out:
# (981665, 152)

# %%
print(list(df.columns))
# Out:
# ['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length', 'home_ownership', 'annual_inc', 'verification_status', 'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose', 'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line', 'fico_range_low', 'fico_range_high', 'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d', 'last_fico_range_high', 'last_fico_range_low', 'collections_12_mths_ex_med', 'mths_since_last_major_derog', 'policy_code', 'application_type', 'annual_inc_joint', 'dti_joint', 'verification_status_joint', 'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m', 'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m', 'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_bc_dlq', 'mths_since_recent_inq', 'mths_since_recent_revol_delinq', 'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit', 'revol_bal_joint', 'sec_app_fico_range_low', 'sec_app_fico_range_high', 'sec_app_earliest_cr_line', 'sec_app_inq_last_6mths', 'sec_app_mort_acc', 'sec_app_open_acc', 'sec_app_revol_util', 'sec_app_open_act_il', 'sec_app_num_rev_accts', 'sec_app_chargeoff_within_12_mths', 'sec_app_collections_12_mths_ex_med', 'sec_app_mths_since_last_major_derog', 'hardship_flag', 'hardship_type', 'hardship_reason', 'hardship_status', 'deferral_term', 'hardship_amount', 'hardship_start_date', 'hardship_end_date', 'payment_plan_start_date', 'hardship_length', 'hardship_dpd', 'hardship_loan_status', 'orig_projected_additional_accrued_interest', 'hardship_payoff_balance_amount', 'hardship_last_payment_amount', 'disbursement_method', 'debt_settlement_flag', 'debt_settlement_flag_date', 'settlement_status', 'settlement_date', 'settlement_amount', 'settlement_percentage', 'settlement_term', 'test_set']

# %%
df.head(5)
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  104046719        NaN    14000.0      14000.0          14000.0   36 months
# 1  104048967        NaN     5000.0       5000.0           5000.0   36 months
# 2  104028593        NaN     4600.0       4600.0           4600.0   36 months
# 3  104046702        NaN    14000.0      14000.0          14000.0   60 months
# 4  104280113        NaN    15000.0      15000.0          15000.0   36 months
#
#   int_rate  installment grade sub_grade                  emp_title emp_length  \
# 0   15.99%       492.13     C        C5             Project Leader  10+ years
# 1   25.49%       200.10     E        E4                      Pilot  10+ years
# 2   11.39%       151.45     B        B3           cable technician    4 years
# 3   12.74%       316.69     C        C1            Specialty Sales    4 years
# 4    5.32%       451.73     A        A1  Executive Account Manager  10+ years
#
#   home_ownership  annual_inc verification_status   issue_d loan_status  \
# 
0
#
#    inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0           0.0                   3.0      11257.0         29762.0     63.4
# 1           6.0                   6.0       4069.0         37522.0     18.8
# 2           1.0                   5.0       1375.0          9610.0     33.7
# 3           0.0                   7.0       2579.0         27153.0     48.3
# 4           0.0                   4.0      17963.0         55203.0     26.0
#
#    chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 0                       0.0          0.0               140.0
# 1                       0.0          0.0                83.0
# 2                       0.0          0.0                77.0
# 3                       0.0          0.0               129.0
# 4                       0.0          0.0                92.0
#
#    mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                 250.0                   13.0            13.0       6.0
# 1                  87.0                    5.0             5.0       0.0
# 2                 159.0                    1.0             1.0       0.0
# 3                 517.0                    1.0             1.0       1.0
# 4                 508.0                    8.0             8.0       5.0
#
#    mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                  13.0                       NaN                   13.0
# 1                   5.0                       NaN                    0.0
# 2                   7.0                       NaN                    1.0
# 3                   2.0                       NaN                   23.0
# 4                   8.0                       NaN                   17.0
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                             NaN                    0.0             7.0
# 1                             NaN                    0.0             2.0
# 2                             NaN                    0.0             2.0
# 3                             NaN                    0.0             7.0
# 4                             NaN                    0.0             3.0
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0              9.0          8.0       13.0        4.0           14.0
# 1              2.0          7.0        8.0        7.0            7.0
# 2              3.0          3.0        4.0        2.0            6.0
# 3              9.0          8.0       13.0        1.0           10.0
# 4              6.0          7.0       11.0        9.0           10.0
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0           21.0                  9.0      18.0               0.0
# 1            8.0                  2.0      11.0               0.0
# 2            9.0                  3.0       7.0               0.0
# 3           21.0                  9.0      10.0               0.0
# 4           16.0                  6.0      13.0               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0           0.0                 0.0                 0.0           100.0
# 1           0.0                 0.0                 4.0           100.0
# 2           0.0                 0.0                 2.0           100.0
# 3           0.0                 0.0                 5.0           100.0
# 4           0.0                 0.0                 2.0           100.0
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0              25.0                   0.0        0.0         286204.0
# 1               0.0                   0.0        0.0         100763.0
# 2               0.0                   0.0        0.0          40000.0
# 3              37.5                   0.0        0.0          55800.0
# 4               0.0                   0.0        0.0         325464.0
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0           104008.0         81400.0                     60167.0
# 1            44754.0         46200.0                     49814.0
# 2             9625.0         14500.0                     11700.0
# 3            25787.0         52500.0                         0.0
# 4            50766.0         74600.0                      4508.0
#
#    revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 0              NaN                     NaN                      NaN
# 1              NaN                     NaN                      NaN
# 2              NaN                     NaN                      NaN
# 3              NaN                     NaN                      NaN
# 4              NaN                     NaN                      NaN
#
#   sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 0                      NaN                     NaN               NaN
# 1                      NaN                     NaN               NaN
# 2                      NaN                     NaN               NaN
# 3                      NaN                     NaN               NaN
# 4                      NaN                     NaN               NaN
#
#    sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 0               NaN                 NaN                  NaN
# 1               NaN                 NaN                  NaN
# 2               NaN                 NaN                  NaN
# 3               NaN                 NaN                  NaN
# 4               NaN                 NaN                  NaN
#
#    sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#    sec_app_collections_12_mths_ex_med  sec_app_mths_since_last_major_derog  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#   hardship_flag hardship_type hardship_reason hardship_status  deferral_term  \
# 0             N           NaN             NaN             NaN            NaN
# 1             N           NaN             NaN             NaN            NaN
# 2             N           NaN             NaN             NaN            NaN
# 3             N           NaN             NaN             NaN            NaN
# 4             N           NaN             NaN             NaN            NaN
#
#    hardship_amount hardship_start_date hardship_end_date  \
# 0              NaN                 NaN               NaN
# 1              NaN                 NaN               NaN
# 2              NaN                 NaN               NaN
# 3              NaN                 NaN               NaN
# 4              NaN                 NaN               NaN
#
#   payment_plan_start_date  hardship_length  hardship_dpd hardship_loan_status  \
# 0                     NaN              NaN           NaN                  NaN
# 1                     NaN              NaN           NaN                  NaN
# 2                     NaN              NaN           NaN                  NaN
# 3                     NaN              NaN           NaN                  NaN
# 4                     NaN              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount disbursement_method debt_settlement_flag  \
# 0                           NaN                Cash                    N
# 1                           NaN                Cash                    N
# 2                           NaN                Cash                    N
# 3                           NaN                Cash                    N
# 4                           NaN                Cash                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term  test_set
# 0                NaN                    NaN              NaN         1
# 1                NaN                    NaN              NaN         1
# 2                NaN                    NaN              NaN         1
# 3                NaN                    NaN              NaN         1
# 4                NaN                    NaN              NaN         1

# %%
df.dtypes.sort_values().to_frame('feature_type').groupby(by = 'feature_type').size().to_frame('count').reset_index()
# Out:
#   feature_type  count
# 0        int64      1
# 1      float64    111
# 2       object     40

# %%
# Analizar una variable concreta
df.loan_status.value_counts()
# Out:
# Current               500937
# Fully Paid            358629
# Charged Off            99099
# Late (31-120 days)     13203
# In Grace Period         6337
# Late (16-30 days)       3414
# Default                   36
# Name: loan_status, dtype: int64

# %%
# analizar nulos
df_dtypes = pd.merge(df.isnull().sum(axis = 0).sort_values().to_frame('missing_value').reset_index(),
         df.dtypes.to_frame('feature_type').reset_index(),
         on = 'index',
         how = 'inner')

# %%
df_dtypes.sort_values(['missing_value', 'feature_type'])
# Out:
#                                           index  missing_value feature_type
# 1                                      test_set              0        int64
# 0                                            id              0       object
# 2                                     loan_amnt             10      float64
# 3                               tot_hi_cred_lim             10      float64
# 4                                   tot_cur_bal             10      float64
# 5                                  tot_coll_amt             10      float64
# 6                                acc_now_delinq             10      float64
# 7                             total_bal_ex_mort             10      float64
# 8                                total_bc_limit             10      float64
# 9                    total_il_high_credit_limit             10      float64
# 11                                  policy_code             10      float64
# 13                   collections_12_mths_ex_med             10      float64
# 14                          last_fico_range_low             10      float64
# 15                         last_fico_range_high             10      float64
# 16                              num_actv_rev_tl             10      float64
# 17                              last_pymnt_amnt             10      float64
# 18                      collection_recovery_fee             10      float64
# 19                                   recoveries             10      float64
# 20                                    tax_liens             10      float64
# 21                           total_rec_late_fee             10      float64
# 22                         pub_rec_bankruptcies             10      float64
# 23                           num_tl_op_past_12m             10      float64
# 24                               num_actv_bc_tl             10      float64
# 25                        num_accts_ever_120_pd             10      float64
# 26                                    num_bc_tl             10      float64
# 27                                     mort_acc             10      float64
# 28                               mo_sin_rcnt_tl             10      float64
# 29                        mo_sin_rcnt_rev_tl_op             10      float64
# 30                         mo_sin_old_rev_tl_op             10      float64
# 31                                  delinq_amnt             10      float64
# 32                     chargeoff_within_12_mths             10      float64
# 33                         acc_open_past_24mths             10      float64
# 34                                    num_il_tl             10      float64
# 35                                num_op_rev_tl             10      float64
# 36                             total_rev_hi_lim             10      float64
# 37                          num_rev_tl_bal_gt_0             10      float64
# 38                                     num_sats             10      float64
# 39                                 num_tl_30dpd             10      float64
# 40                           num_tl_90g_dpd_24m             10      float64
# 41                               pct_tl_nvr_dlq             10      float64
# 42                                total_rec_int             10      float64
# 43                                  num_bc_sats             10      float64
# 44                              total_pymnt_inv             10      float64
# 46                              total_rec_prncp             10      float64
# 51                                   annual_inc             10      float64
# 55                                  installment             10      float64
# 58                              funded_amnt_inv             10      float64
# 59                                  funded_amnt             10      float64
# 63                                    out_prncp             10      float64
# 64                                  delinq_2yrs             10      float64
# 66                                    revol_bal             10      float64
# 67                                      pub_rec             10      float64
# 68                                     open_acc             10      float64
# 70                                out_prncp_inv             10      float64
# 71                                    total_acc             10      float64
# 72                              fico_range_high             10      float64
# 73                               fico_range_low             10      float64
# 74                                  total_pymnt             10      float64
# 76                               inq_last_6mths             10      float64
# 10                             application_type             10       object
# 12                                hardship_flag             10       object
# 45                         debt_settlement_flag             10       object
# 47                                   pymnt_plan             10       object
# 48                                  loan_status             10       object
# 49                                      issue_d             10       object
# 50                          verification_status             10       object
# 52                               home_ownership             10       object
# 53                                    sub_grade             10       object
# 54                                        grade             10       object
# 56                                     int_rate             10       object
# 57                                         term             10       object
# 60                                      purpose             10       object
# 61                                   addr_state             10       object
# 62                                          url             10       object
# 65                          initial_list_status             10       object
# 69                          disbursement_method             10       object
# 75                             earliest_cr_line             10       object
# 77                                num_rev_accts             11      float64
# 78                                     zip_code             11       object
# 79                                  avg_cur_bal             23      float64
# 80                           last_credit_pull_d             50       object
# 81                                        title            142       object
# 82                                          dti            304      float64
# 83                                   revol_util            550       object
# 84                                 last_pymnt_d            878       object
# 85                         mths_since_recent_bc           9718      float64
# 86                               bc_open_to_buy          10282      float64
# 87                             percent_bc_gt_75          10677      float64
# 88                                      bc_util          10862      float64
# 89                           mo_sin_old_il_acct          28220      float64
# 90                             num_tl_120dpd_2m          42519      float64
# 91                                   emp_length          57995       object
# 92                                    emp_title          59595       object
# 93                        mths_since_recent_inq         103454      float64
# 94                                 next_pymnt_d         457738       object
# 95                       mths_since_last_delinq         477730      float64
# 96               mths_since_recent_revol_delinq         631372      float64
# 97                                  total_cu_tl         635362      float64
# 98                                 inq_last_12m         635362      float64
# 99                                  open_acc_6m         635362      float64
# 100                                 open_act_il         635362      float64
# 101                                 open_il_12m         635362      float64
# 102                                 open_il_24m         635362      float64
# 103                                total_bal_il         635362      float64
# 104                                      inq_fi         635362      float64
# 105                                 open_rv_24m         635362      float64
# 106                                  max_bal_bc         635362      float64
# 107                                 open_rv_12m         635362      float64
# 108                                    all_util         635392      float64
# 109                          mths_since_rcnt_il         644709      float64
# 110                                     il_util         681303      float64
# 111                 mths_since_last_major_derog         702961      float64
# 112                    mths_since_recent_bc_dlq         732439      float64
# 113                      mths_since_last_record         807460      float64
# 115                            annual_inc_joint         955940      float64
# 114                   verification_status_joint         955940       object
# 116                                   dti_joint         955942      float64
# 117          sec_app_collections_12_mths_ex_med         959840      float64
# 118            sec_app_chargeoff_within_12_mths         959840      float64
# 119                         sec_app_open_act_il         959840      float64
# 120                            sec_app_open_acc         959840      float64
# 121                       sec_app_num_rev_accts         959840      float64
# 122                      sec_app_inq_last_6mths         959840      float64
# 124                     sec_app_fico_range_high         959840      float64
# 125                      sec_app_fico_range_low         959840      float64
# 126                            sec_app_mort_acc         959840      float64
# 127                             revol_bal_joint         959840      float64
# 123                    sec_app_earliest_cr_line         959840       object
# 128                          sec_app_revol_util         960128      float64
# 129                                        desc         966341       object
# 132                           settlement_amount         973035      float64
# 133                       settlement_percentage         973035      float64
# 134                             settlement_term         973035      float64
# 130                   debt_settlement_flag_date         973035       object
# 131                           settlement_status         973035       object
# 135                             settlement_date         973035       object
# 136         sec_app_mths_since_last_major_derog         974124      float64
# 137                hardship_last_payment_amount         978661      float64
# 138              hardship_payoff_balance_amount         978661      float64
# 140                                hardship_dpd         978661      float64
# 141                             hardship_length         978661      float64
# 144                             hardship_amount         978661      float64
# 145                               deferral_term         978661      float64
# 139                     payment_plan_start_date         978661       object
# 142                           hardship_end_date         978661       object
# 143                         hardship_start_date         978661       object
# 146                             hardship_reason         978661       object
# 147                               hardship_type         978661       object
# 148                        hardship_loan_status         978661       object
# 149                             hardship_status         978661       object
# 150  orig_projected_additional_accrued_interest         979086      float64
# 151                                   member_id         981665      float64

# %%
# Check columns have more than  400000  missing values ( ≈90% )
missing_df = df.isnull().sum(axis = 0).sort_values().to_frame('missing_value').reset_index()

# %%
miss_4000 = list(missing_df[missing_df.missing_value >= 400000]['index'])

# %%
print(len(miss_4000))
# Out:
# 58

# %%
print(sorted(miss_4000))
# Out:
# ['all_util', 'annual_inc_joint', 'debt_settlement_flag_date', 'deferral_term', 'desc', 'dti_joint', 'hardship_amount', 'hardship_dpd', 'hardship_end_date', 'hardship_last_payment_amount', 'hardship_length', 'hardship_loan_status', 'hardship_payoff_balance_amount', 'hardship_reason', 'hardship_start_date', 'hardship_status', 'hardship_type', 'il_util', 'inq_fi', 'inq_last_12m', 'max_bal_bc', 'member_id', 'mths_since_last_delinq', 'mths_since_last_major_derog', 'mths_since_last_record', 'mths_since_rcnt_il', 'mths_since_recent_bc_dlq', 'mths_since_recent_revol_delinq', 'next_pymnt_d', 'open_acc_6m', 'open_act_il', 'open_il_12m', 'open_il_24m', 'open_rv_12m', 'open_rv_24m', 'orig_projected_additional_accrued_interest', 'payment_plan_start_date', 'revol_bal_joint', 'sec_app_chargeoff_within_12_mths', 'sec_app_collections_12_mths_ex_med', 'sec_app_earliest_cr_line', 'sec_app_fico_range_high', 'sec_app_fico_range_low', 'sec_app_inq_last_6mths', 'sec_app_mort_acc', 'sec_app_mths_since_last_major_derog', 'sec_app_num_rev_accts', 'sec_app_open_acc', 'sec_app_open_act_il', 'sec_app_revol_util', 'settlement_amount', 'settlement_date', 'settlement_percentage', 'settlement_status', 'settlement_term', 'total_bal_il', 'total_cu_tl', 'verification_status_joint']
